# %% [markdown]
# ## Data Structures
#
# - Pandas provides two primary data structures for handling data:
#
# 1. Series: A one-dimensional labeled array, similar to a list or NumPy array, but with labeled indices.
# 2. DataFrame: A two-dimensional labeled data structure, similar to a table or a spreadsheet, with rows and columns.

# %% [markdown]
# ## 1. Pandas Series:
#
# A Series is essentially a single column of data. It can hold data of any type (integer, float, string, etc.) and comes with an index that labels each data element.
#
#
# -> Creating a Pandas Series:

# %%
import pandas as pd

# Creating a Series from a list
series1 = pd.Series([10, 20, 30, 40, 50])

# Printing the Series
print(series1)
# Out:
# 0    10
# 1    20
# 2    30
# 3    40
# 4    50
# dtype: int64

# %% [markdown]
# - The left column (0, 1, 2, ...) represents the index (default integers).
# - The right column represents the values in the Series.

# %% [markdown]
# -> Creating a Series with Custom Index:

# %%
# Creating a Series with custom index
series2 = pd.Series([10, 20, 30, 40, 50], index=['a', 'b', 'c', 'd', 'e'])

# Printing the Series
print(series2)
# Out:
# a    10
# b    20
# c    30
# d    40
# e    50
# dtype: int64

# %% [markdown]
# -> Accessing Data in Series:

# %%
# Accessing data by index
print(series2['b'])  # Output: 20
# Out:
# 20

# %% [markdown]
# ## 2. Pandas DataFrame:
#
# A DataFrame is a two-dimensional labeled data structure with columns and rows. It can be thought of as a table, where each column can have different types of data (e.g., numeric, string, etc.).

# %%
# Creating a DataFrame from a dictionary
data = {
    'Name': ['Alice', 'Bob', 'Charlie', 'David'],
    'Age': [25, 30, 35, 40],
    'City': ['New York', 'Los Angeles', 'Chicago', 'Houston']
}

df = pd.DataFrame(data)

# Printing the DataFrame
print(df)
# Out:
#       Name  Age         City
# 0    Alice   25     New York
# 1      Bob   30  Los Angeles
# 2  Charlie   35      Chicago
# 3    David   40      Houston

# %% [markdown]
# - The rows (0, 1, 2, 3) represent the index (default integers).
# - The columns ('Name', 'Age', 'City') represent different attributes.
# - The values in the DataFrame are organized in rows and columns.

# %% [markdown]
# -> Creating a DataFrame with Custom Index:

# %%
# Creating a DataFrame with a custom index
df_custom_index = pd.DataFrame(data, index=['a', 'b', 'c', 'd'])

# Printing the DataFrame
print(df_custom_index)
# Out:
#       Name  Age         City
# a    Alice   25     New York
# b      Bob   30  Los Angeles
# c  Charlie   35      Chicago
# d    David   40      Houston

# %% [markdown]
# -> Accessing Data in DataFrame:

# %%
# Accessing a column
print(df['Name'])  # Output: Series of 'Name' column

# Accessing a row by index
print(df.loc[1])   # Output: Row at index 1

# Accessing multiple rows and columns
print(df.loc[0:2, ['Name', 'City']])  # Rows 0, 1, 2 and columns 'Name' and 'City'
# Out:
# 0      Alice
# 1        Bob
# 2    Charlie
# 3      David
# Name: Name, dtype: object
# Name            Bob
# Age              30
# City    Los Angeles
# Name: 1, dtype: object
#       Name         City
# 0    Alice     New York
# 1      Bob  Los Angeles
# 2  Charlie      Chicago

# %%
# print df in a prettier way 
df
# Out:
#       Name  Age         City
# 0    Alice   25     New York
# 1      Bob   30  Los Angeles
# 2  Charlie   35      Chicago
# 3    David   40      Houston

# %% [markdown]
# ## Load a DataFrame from a CSV File

# %%
import pandas as pd

# Load DataFrame from a CSV file
df = pd.read_csv('pokemon_data.csv')

# Show the first few rows of the DataFrame
df
# Out:
#        #                   Name   Type 1  Type 2  HP  Attack  Defense  \
# 0      1              Bulbasaur    Grass  Poison  45      49       49
# 1      2                Ivysaur    Grass  Poison  60      62       63
# 2      3               Venusaur    Grass  Poison  80      82       83
# 3      3  VenusaurMega Venusaur    Grass  Poison  80     100      123
# 4      4             Charmander     Fire     NaN  39      52       43
# ..   ...                    ...      ...     ...  ..     ...      ...
# 795  719                Diancie     Rock   Fairy  50     100      150
# 796  719    DiancieMega Diancie     Rock   Fairy  50     160      110
# 797  720    HoopaHoopa Confined  Psychic   Ghost  80     110       60
# 798  720     HoopaHoopa Unbound  Psychic    Dark  80     160       60
# 799  721              Volcanion     Fire   Water  80     110      120
#
#      Sp. Atk  Sp. Def  Speed  Generation  Legendary
# 0         65       65     45           1      False
# 1         80       80     60           1      False
# 2        100      100     80           1      False
# 3        122      120     80           1      False
# 4         60       50     65           1      False
# ..       ...      ...    ...         ...        ...
# 795      100      150     50           6       True
# 796      160      110    110           6       True
# 797      150      130     70           6       True
# 798      170      130     80           6       True
# 799      130       90     70           6       True
#
# [800 rows x 12 columns]

# %% [markdown]
# ## Load a DataFrame from a txt File

# %%
# This reads from .txt file with space as delimiter
import pandas as pd

# Load DataFrame from a space-delimited .txt file
df = pd.read_csv('pokemon_data.txt', delim_whitespace=True)

# Show the first few rows of the DataFrame
df
# Out:
# /var/folders/hg/7q10m6ks77bcpykgf2nbst5h0000gn/T/ipykernel_82408/2447577944.py:5: FutureWarning: The 'delim_whitespace' keyword in pd.read_csv is deprecated and will be removed in a future version. Use ``sep='\s+'`` instead
#   df = pd.read_csv('pokemon_data.txt', delim_whitespace=True)
#        #          Name      Type        1  Type.1    2   HP  Attack  Defense  \
# 0      1     Bulbasaur     Grass   Poison      45   49   49      65       65
# 1      2       Ivysaur     Grass   Poison      60   62   63      80       80
# 2      3      Venusaur     Grass   Poison      80   82   83     100      100
# 3      3  VenusaurMega  Venusaur    Grass  Poison   80  100     123      122
# 4      4    Charmander      Fire       39      52   43   60      50       65
# ..   ...           ...       ...      ...     ...  ...  ...     ...      ...
# 795  719       Diancie      Rock    Fairy      50  100  150     100      150
# 796  719   DiancieMega   Diancie     Rock   Fairy   50  160     110      160
# 797  720    HoopaHoopa  Confined  Psychic   Ghost   80  110      60      150
# 798  720    HoopaHoopa   Unbound  Psychic    Dark   80  160      60      170
# 799  721     Volcanion      Fire    Water      80  110  120     130       90
#
#      Sp.    Atk  Sp..1    Def Speed  Generation  Legendary
# 0     45      1  FALSE    NaN   NaN         NaN        NaN
# 1     60      1  FALSE    NaN   NaN         NaN        NaN
# 2     80      1  FALSE    NaN   NaN         NaN        NaN
# 3    120     80      1  FALSE   NaN         NaN        NaN
# 4      1  FALSE    NaN    NaN   NaN         NaN        NaN
# ..   ...    ...    ...    ...   ...         ...        ...
# 795   50      6   TRUE    NaN   NaN         NaN        NaN
# 796  110    110      6   TRUE   NaN         NaN        NaN
# 797  130     70      6   TRUE   NaN         NaN        NaN
# 798  130     80      6   TRUE   NaN         NaN        NaN
# 799   70      6   TRUE    NaN   NaN         NaN        NaN
#
# [800 rows x 16 columns]

# %% [markdown]
# ### Reading an Excel file
# ```df = pd.read_excel('data.xlsx')```
# ### Reading a JSON file
# ```df = pd.read_json('data.json')```
